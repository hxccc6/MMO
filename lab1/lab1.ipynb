# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.impute import MissingIndicator
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from IPython.display import Image
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
data = pd.read_csv(r'C:\Users\80667\Desktop\文件\ИУ5\研一下\MMO\数据集\印度人口\india_population.csv')
data.head()
# Out:
#    Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0  2020  1380004385             0.99       13586631         -532687
# 1  2019  1366417754             1.02       13775474         -532687
# 2  2018  1352642280             1.04       13965495         -532687
# 3  2017  1338676785             1.07       14159536         -532687
# 4  2016  1324517249             1.10       14364846         -532687
#
#    Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  Urban Population  \
# 0        28.4            2.24              464         35.0         483098640
# 1        27.1            2.36              460         34.5         471828295
# 2        27.1            2.36              455         34.1         460779764
# 3        27.1            2.36              450         33.6         449963381
# 4        27.1            2.36              445         33.2         439391699
#
#    Country's Share of World Pop  World Population  India Global Rank
# ...

# %%
data.dtypes
# Out:
# Year                              int64
# Population                        int64
# Yearly % Change                 float64
# Yearly Change                     int64
# Migrants (net)                    int64
# Median Age                      float64
# Fertility Rate                  float64
# Density (P/Km²)                   int64
# Urban Pop %                     float64
# Urban Population                  int64
# Country's Share of World Pop    float64
# World Population                  int64
# India Global Rank                 int64
# dtype: object

# %% [markdown]
# ## Рассмотрим распределение рейтинга производительности CPU

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.kdeplot(data=data, x="Density (P/Km²)")
# Out:
# <AxesSubplot:xlabel='Density (P/Km²)', ylabel='Density'>

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.histplot(data['Fertility Rate'], discrete=True)
# Out:
# <AxesSubplot:xlabel='Fertility Rate', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.violinplot(x='Fertility Rate', y='Density (P/Km²)', data=data)
# Out:
# <AxesSubplot:xlabel='Fertility Rate', ylabel='Density (P/Km²)'>

# %%
sns.kdeplot(data=data, x="Fertility Rate", y="Density (P/Km²)")
# Out:
# <AxesSubplot:xlabel='Fertility Rate', ylabel='Density (P/Km²)'>

# %%
sns.scatterplot(x='Yearly % Change', y='Fertility Rate', data=data)
# Out:
# <AxesSubplot:xlabel='Yearly % Change', ylabel='Fertility Rate'>

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(method='pearson'), annot=True, fmt='.2f')
fig.suptitle('Корреляционные матрицы')
# Out:
# Text(0.5, 0.98, 'Корреляционные матрицы')

# %%
sns.pairplot(data)
plt.show()
